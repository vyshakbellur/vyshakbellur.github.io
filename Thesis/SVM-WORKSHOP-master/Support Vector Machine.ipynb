# %%
import numpy as np
from sklearn import datasets
from sklearn import svm
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Dataset Preprocessing

# %%
from sklearn import datasets

# %%
digits = datasets.load_digits()

# %%
images = digits.images

# %%
images.shape

# %%
plt.imshow(images[2], cmap=plt.cm.gray_r)

# %%
x, y = digits.data, digits.target

# %%
x.shape

# %%
y.shape

# %%
y

# %%
split = int(x.shape[0]*0.7)

# %%
train_x = x[: split, :]
test_x = x[split:, :]
train_y = y[: split]
test_y = y[split: ]

# %%
train_x.shape

# %% [markdown]
# ## Build Model

# %%
from sklearn import svm

# %%
clf = svm.SVC(gamma=0.001, C=1)

# %%
clf.fit(train_x, train_y)

# %%
num = 2
plt.imshow(images[split+num], cmap=plt.cm.gray_r)

# %%
clf.predict(test_x[num].reshape(1, -1))

# %%
test_y[num]

# %% [markdown]
# ## Evaluate Model

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(train_y, clf.predict(train_x))

# %%
accuracy_score(test_y, clf.predict(test_x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7585c6119ada> in <module>()
# ----> 1 accuracy_score(test_y, clf.predict(test_x))
#
# NameError: name 'test_y' is not defined

# %%
incorrect = np.where(clf.predict(test_x) != test_y)
incorrect
